# %%
import pandas as pd

# %%
df=pd.read_csv('virat.csv')

# %%
df
# Out:
#     Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12   33   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37   82   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25   40   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54   87   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31   45   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..   ...  ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122  147  105   8   5  116.19    3    caught     2      v England
# 130    8    6    5   2   0     160    3    caught     1      v England
# 131   55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        132 non-null    object
#  1   Mins        132 non-null    object
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          132 non-null    object
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 12.5+ KB

# %%
df['Runs'] = pd.to_numeric(df['Runs'], errors='coerce')
df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
df['SR'] = pd.to_numeric(df['SR'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        115 non-null    float64
#  1   Mins        126 non-null    float64
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          131 non-null    float64
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 12.5+ KB

# %%
df.groupby(by=['Opposition'])[['Runs', 'BF', '6s', '4s']].mean()
# Out:
#                      Runs         BF        6s        4s
# Opposition
# v Australia     43.555556  50.850000  0.650000  4.750000
# v Bangladesh    57.000000  68.750000  0.625000  6.375000
# v England       32.588235  42.285714  0.523810  3.857143
# v Ireland       34.000000  53.000000  0.000000  3.000000
# v Netherlands   12.000000  20.000000  0.000000  2.000000
# v New Zealand   52.272727  62.571429  0.928571  5.642857
# v Pakistan       5.500000  13.000000  0.000000  0.500000
# v South Africa  33.642857  45.600000  0.666667  2.400000
# v Sri Lanka     38.809524  52.041667  0.375000  4.500000
# v West Indies   54.777778  57.000000  0.473684  5.210526
# v Zimbabwe      36.750000  48.600000  0.400000  4.200000

# %%
df.loc[:,['Runs','Mins']]
# Out:
#       Runs   Mins
# 0     12.0   33.0
# 1     37.0   82.0
# 2     25.0   40.0
# 3     54.0   87.0
# 4     31.0   45.0
# ..     ...    ...
# 127   45.0   64.0
# 128   65.0  152.0
# 129  122.0  147.0
# 130    8.0    6.0
# 131   55.0   81.0
#
# [132 rows x 2 columns]

# %%
df.iloc[:,[0,1,2]]
# Out:
#       Runs   Mins   BF
# 0     12.0   33.0   22
# 1     37.0   82.0   67
# 2     25.0   40.0   38
# 3     54.0   87.0   66
# 4     31.0   45.0   46
# ..     ...    ...  ...
# 127   45.0   64.0   51
# 128   65.0  152.0   76
# 129  122.0  147.0  105
# 130    8.0    6.0    5
# 131   55.0   81.0   63
#
# [132 rows x 3 columns]

# %%
df.rename(columns={'Start Date':'Start_Date'}, inplace=True)
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37.0   82.0   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25.0   40.0   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122.0  147.0  105   8   5  116.19    3    caught     2      v England
# 130    8.0    6.0    5   2   0  160.00    3    caught     1      v England
# 131   55.0   81.0   63   8   0   87.30    3    caught     2      v England
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
products=['Lenovo','Acer','Dell','HP','Asus']

# %%
type(products)
# Out:
# list

# %%
products
# Out:
# ['Lenovo', 'Acer', 'Dell', 'HP', 'Asus']

# %%
a=pd.Series(products)
a
# Out:
# 0    Lenovo
# 1      Acer
# 2      Dell
# 3        HP
# 4      Asus
# dtype: object

# %%
products=['Lenovo','Acer','Dell','HP','Asus']
Quantity=[1,2,3,4,5]
df=pd.DataFrame({'Prod':products,'Quan':Quantity})
df
# Out:
#      Prod  Quan
# 0  Lenovo     1
# 1    Acer     2
# 2    Dell     3
# 3      HP     4
# 4    Asus     5

# %%
df.iloc[[0,1,4],:]
# Out:
#      Prod  Quan
# 0  Lenovo     1
# 1    Acer     2
# 4    Asus     5

# %%
df=pd.read_csv('virat.csv')
df
# Out:
#     Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12   33   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37   82   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25   40   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54   87   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31   45   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..   ...  ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122  147  105   8   5  116.19    3    caught     2      v England
# 130    8    6    5   2   0     160    3    caught     1      v England
# 131   55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# ...

# %%
df.head(10)
# Out:
#   Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0   12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1   37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2   25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3   54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4   31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
# 5   2*    6   2   0   0    100    7   not out     1  v Sri Lanka
# 6   30   53  41   3   0  73.17    4    caught     2  v Australia
# 7   10   32  16   1   0   62.5    3    caught     2  v Australia
# 8   27   20  19   4   0  142.1    7    bowled     1  v Sri Lanka
# 9   54   93  65   7   0  83.07    4       lbw     1  v Sri Lanka
#
#           Ground Start Date
# 0       Dambulla  18-Aug-08
# 1       Dambulla  20-Aug-08
# 2  Colombo (RPS)  24-Aug-08
# 3  Colombo (RPS)  27-Aug-08
# 4  Colombo (RPS)  29-Aug-08
# 5  Colombo (RPS)  14-Sep-09
# 6       Vadodara  25-Oct-09
# ...

# %%
df.tail(10)
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 122   106  131   92  11   1  115.21    3    caught     2    v Australia
# 123     8   11   11   1   0   72.72    3    caught     2    v Australia
# 124   85*  109   81   9   1  104.93    3   not out     2  v New Zealand
# 125     9   18   13   1   0   69.23    3    caught     2  v New Zealand
# 126  154*  202  134  16   1  114.92    3   not out     2  v New Zealand
# 127    45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128    65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129   122  147  105   8   5  116.19    3    caught     2      v England
# 130     8    6    5   2   0     160    3    caught     1      v England
# 131    55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date
# 122       Canberra  20-Jan-16
# 123         Sydney  23-Jan-16
# 124     Dharamsala  16-Oct-16
# 125          Delhi  20-Oct-16
# ...

# %%
df.shape
# Out:
# (132, 12)

# %%
df.columns.to_list()
# Out:
# ['Runs',
#  'Mins',
#  'BF',
#  '4s',
#  '6s',
#  'SR',
#  'Pos',
#  'Dismissal',
#  'Inns',
#  'Opposition',
#  'Ground',
#  'Start Date']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        132 non-null    object
#  1   Mins        132 non-null    object
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          132 non-null    object
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 12.5+ KB

# %%
df.describe()
# Out:
#                BF          4s          6s         Pos        Inns
# count  132.000000  132.000000  132.000000  132.000000  132.000000
# mean    50.871212    4.371212    0.545455    3.303030    1.575758
# std     38.729716    4.404032    1.086795    0.873174    0.496110
# min      0.000000    0.000000    0.000000    1.000000    1.000000
# 25%     17.750000    1.000000    0.000000    3.000000    1.000000
# 50%     42.500000    3.000000    0.000000    3.000000    2.000000
# 75%     82.250000    7.000000    1.000000    4.000000    2.000000
# max    140.000000   18.000000    7.000000    7.000000    2.000000

# %%
df['Runs']=pd.to_numeric(df['Runs'], errors='coerce')
df['Mins']=pd.to_numeric(df['Mins'], errors='coerce')
df['SR']=pd.to_numeric(df['SR'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        115 non-null    float64
#  1   Mins        126 non-null    float64
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          131 non-null    float64
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 12.5+ KB

# %%
df.describe()
# Out:
#              Runs        Mins          BF          4s          6s          SR  \
# count  115.000000  126.000000  132.000000  132.000000  132.000000  131.000000
# mean    41.234783   70.492063   50.871212    4.371212    0.545455   77.578931
# std     38.883616   57.270131   38.729716    4.404032    1.086795   37.410776
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      9.000000   18.250000   17.750000    1.000000    0.000000   61.980000
# 50%     28.000000   56.000000   42.500000    3.000000    0.000000   78.780000
# 75%     64.500000  120.750000   82.250000    7.000000    1.000000  100.000000
# max    138.000000  202.000000  140.000000   18.000000    7.000000  209.090000
#
#               Pos        Inns
# count  132.000000  132.000000
# mean     3.303030    1.575758
# std      0.873174    0.496110
# min      1.000000    1.000000
# 25%      3.000000    1.000000
# 50%      3.000000    2.000000
# 75%      4.000000    2.000000
# ...

# %%
df.rename({'Start Date':'Start_Date'}, axis=1, inplace=True)

# %%
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37.0   82.0   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25.0   40.0   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122.0  147.0  105   8   5  116.19    3    caught     2      v England
# 130    8.0    6.0    5   2   0  160.00    3    caught     1      v England
# 131   55.0   81.0   63   8   0   87.30    3    caught     2      v England
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %%
df['Runs']
# Out:
# 0       12.0
# 1       37.0
# 2       25.0
# 3       54.0
# 4       31.0
#        ...
# 127     45.0
# 128     65.0
# 129    122.0
# 130      8.0
# 131     55.0
# Name: Runs, Length: 132, dtype: float64

# %%
df.Runs
# Out:
# 0       12.0
# 1       37.0
# 2       25.0
# 3       54.0
# 4       31.0
#        ...
# 127     45.0
# 128     65.0
# 129    122.0
# 130      8.0
# 131     55.0
# Name: Runs, Length: 132, dtype: float64

# %%
my_col=['Runs','Mins','SR']

# %%
df[my_col]
# Out:
#       Runs   Mins      SR
# 0     12.0   33.0   54.54
# 1     37.0   82.0   55.22
# 2     25.0   40.0   65.78
# 3     54.0   87.0   81.81
# 4     31.0   45.0   67.39
# ..     ...    ...     ...
# 127   45.0   64.0   88.23
# 128   65.0  152.0   85.52
# 129  122.0  147.0  116.19
# 130    8.0    6.0  160.00
# 131   55.0   81.0   87.30
#
# [132 rows x 3 columns]

# %% [markdown]
# ### Conditional Pandas

# %%
df[df['Runs']>=100]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos   Dismissal  Inns      Opposition  \
# 10   107.0    NaN  114  11   1   93.85    4      caught     2     v Sri Lanka
# 21   118.0  193.0  121  11   1   97.52    3      caught     2     v Australia
# 22   105.0  162.0  104  10   0  100.96    3      caught     1   v New Zealand
# 47   107.0  102.0   93   9   1  115.05    4  hit wicket     1       v England
# 54   117.0  154.0  123  14   0   95.12    4      caught     2   v West Indies
# 63   106.0  158.0  113   9   0   93.80    3      caught     1     v Sri Lanka
# 78   102.0  120.0   83  13   2  122.89    3      caught     1   v West Indies
# 79   115.0  133.0  108  13   1  106.48    3      caught     2      v Zimbabwe
# 92   123.0  179.0  111  11   2  110.81    3      caught     2   v New Zealand
# 96   136.0  157.0  122  16   2  111.47    3      bowled     2    v Bangladesh
# 103  127.0  164.0  114  13   3  111.40    3     run out     1   v West Indies
# ...

# %% [markdown]
# ### Scored century and caught behind the wickets '&'

# %%
df[(df['Runs'] >= 100) & (df['Dismissal'] == 'caught')]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns      Opposition  \
# 10   107.0    NaN  114  11   1   93.85    4    caught     2     v Sri Lanka
# 21   118.0  193.0  121  11   1   97.52    3    caught     2     v Australia
# 22   105.0  162.0  104  10   0  100.96    3    caught     1   v New Zealand
# 54   117.0  154.0  123  14   0   95.12    4    caught     2   v West Indies
# 63   106.0  158.0  113   9   0   93.80    3    caught     1     v Sri Lanka
# 78   102.0  120.0   83  13   2  122.89    3    caught     1   v West Indies
# 79   115.0  133.0  108  13   1  106.48    3    caught     2      v Zimbabwe
# 92   123.0  179.0  111  11   2  110.81    3    caught     2   v New Zealand
# 117  138.0  202.0  140   6   5   98.57    3    caught     1  v South Africa
# 121  117.0  174.0  117   7   2  100.00    3    caught     1     v Australia
# 122  106.0  131.0   92  11   1  115.21    3    caught     2     v Australia
# ...

# %% [markdown]
# ### Scored century and caught behind the wickets and against australia

# %%
df[(df['Runs'] >= 100) & (df['Dismissal'] == 'caught') & (df['Opposition'] == 'vAustralia')]
# Out:
# Empty DataFrame
# Columns: [Runs, Mins, BF, 4s, 6s, SR, Pos, Dismissal, Inns, Opposition, Ground, Start_Date]
# Index: []

# %%
df[(df['Runs']>100) &(df['Dismissal']=='caught') & (df['Opposition']=='v Australia')]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 21   118.0  193.0  121  11   1   97.52    3    caught     2  v Australia
# 121  117.0  174.0  117   7   2  100.00    3    caught     1  v Australia
# 122  106.0  131.0   92  11   1  115.21    3    caught     2  v Australia
#
#             Ground Start_Date
# 21   Visakhapatnam  20-Oct-10
# 121      Melbourne  17-Jan-16
# 122       Canberra  20-Jan-16

# %%
df[(df['Runs'] >= 100) & (df['Dismissal'] == 'caught') & (df['Opposition'] == 'v Australia')]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 21   118.0  193.0  121  11   1   97.52    3    caught     2  v Australia
# 121  117.0  174.0  117   7   2  100.00    3    caught     1  v Australia
# 122  106.0  131.0   92  11   1  115.21    3    caught     2  v Australia
#
#             Ground Start_Date
# 21   Visakhapatnam  20-Oct-10
# 121      Melbourne  17-Jan-16
# 122       Canberra  20-Jan-16

# %% [markdown]
# ### Scored century or SR < 80  '|'

# %%
df[(df['Runs']>100) | (df['SR']<80)]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37.0   82.0   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25.0   40.0   38   4   0   65.78    1   run out     1    v Sri Lanka
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2    v Sri Lanka
# 6     30.0   53.0   41   3   0   73.17    4    caught     2    v Australia
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 121  117.0  174.0  117   7   2  100.00    3    caught     1    v Australia
# 122  106.0  131.0   92  11   1  115.21    3    caught     2    v Australia
# 123    8.0   11.0   11   1   0   72.72    3    caught     2    v Australia
# 125    9.0   18.0   13   1   0   69.23    3    caught     2  v New Zealand
# 129  122.0  147.0  105   8   5  116.19    3    caught     2      v England
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %%
df[~(df['Runs']>50)]
# Out:
#      Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0    12.0   33.0   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1    37.0   82.0   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2    25.0   40.0   38   4   0   65.78    1   run out     1    v Sri Lanka
# 4    31.0   45.0   46   3   1   67.39    1       lbw     2    v Sri Lanka
# 5     NaN    6.0    2   0   0  100.00    7   not out     1    v Sri Lanka
# ..    ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 124   NaN  109.0   81   9   1  104.93    3   not out     2  v New Zealand
# 125   9.0   18.0   13   1   0   69.23    3    caught     2  v New Zealand
# 126   NaN  202.0  134  16   1  114.92    3   not out     2  v New Zealand
# 127  45.0   64.0   51   2   1   88.23    3    caught     2  v New Zealand
# 130   8.0    6.0    5   2   0  160.00    3    caught     1      v England
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %% [markdown]
# ### Donot show any records where SR < = 100 and 4s>6

# %%
df[~((df['SR']<=100) & (df['4s']>6))]
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37.0   82.0   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25.0   40.0   38   4   0   65.78    1   run out     1    v Sri Lanka
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2    v Sri Lanka
# 5      NaN    6.0    2   0   0  100.00    7   not out     1    v Sri Lanka
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 126    NaN  202.0  134  16   1  114.92    3   not out     2  v New Zealand
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122.0  147.0  105   8   5  116.19    3    caught     2      v England
# 130    8.0    6.0    5   2   0  160.00    3    caught     1      v England
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %%
df.sort_values(by='Runs', ascending=True)
# Out:
#      Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 19    0.0    5.0    3   0   0    0.00    3    caught     2    v Sri Lanka
# 42    0.0    1.0    1   0   0    0.00    3       lbw     2  v West Indies
# 75    0.0    1.0    1   0   0    0.00    3    caught     1      v England
# 86    0.0    4.0    3   0   0    0.00    3   run out     1    v Australia
# 15    0.0    3.0    0   0   0     NaN    3   run out     1     v Zimbabwe
# ..    ...    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 85    NaN  104.0   66  18   1  174.24    3   not out     2    v Australia
# 99    NaN    9.0    3   0   0   33.33    3   not out     2      v England
# 108   NaN  192.0  126  12   3  110.31    4   not out     2    v Sri Lanka
# 124   NaN  109.0   81   9   1  104.93    3   not out     2  v New Zealand
# 126   NaN  202.0  134  16   1  114.92    3   not out     2  v New Zealand
#
#           Ground Start_Date
# 19      Dambulla  16-Aug-10
# ...

# %% [markdown]
# ### Highest runs scored by Virat against Australia

# %%
abc=df[df['Opposition']=='v Australia']

# %%
abc.sort_values(by='Runs', ascending=False).head(1)
# Out:
#       Runs   Mins   BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 117  138.0  202.0  140   6   5  98.57    3    caught     1  v Australia
#
#       Ground Start_Date
# 117  Chennai  22-Oct-15

# %%
df[df.Ground.isin(['Mohali','Ranchi'])]
# Out:
#      Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 7    10.0   32.0   16   1   0   62.50    3    caught     2  v Australia
# 38    9.0   20.0   21   0   0   42.85    4    caught     1  v Australia
# 50   35.0   42.0   30   5   0  116.66    4       lbw     2  v Australia
# 73    NaN  110.0   79   9   2   97.46    3   not out     2  v Australia
# 74   26.0   44.0   33   3   0   78.78    3    caught     2  v Australia
# 84   68.0  121.0   73   9   0   93.15    3    caught     1  v Australia
# 108   NaN  192.0  126  12   3  110.31    4   not out     2  v Australia
# 126   NaN  202.0  134  16   1  114.92    3   not out     2  v Australia
# 127  45.0   64.0   51   2   1   88.23    3    caught     2  v Australia
#
#      Ground Start_Date
# 7    Mohali   2-Nov-09
# 38   Mohali  30-Mar-11
# 50   Mohali  20-Oct-11
# 73   Ranchi  19-Jan-13
# 74   Mohali  23-Jan-13
# 84   Mohali  19-Oct-13
# 108  Ranchi  16-Nov-14
# 126  Mohali  23-Oct-16
# 127  Ranchi  26-Oct-16

# %%
df['Dismissal'].unique().tolist()
# Out:
# ['lbw', 'caught', 'run out', 'bowled', 'not out', 'stumped', 'hit wicket']

# %%
df['Dismissal'].nunique()
# Out:
# 7

# %%
df['Opposition'].unique()
# Out:
# array(['v Australia'], dtype=object)

# %%
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1  v Australia
# 1     37.0   82.0   67   6   0   55.22    2    caught     2  v Australia
# 2     25.0   40.0   38   4   0   65.78    1   run out     1  v Australia
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1  v Australia
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2  v Australia
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...          ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v Australia
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v Australia
# 129  122.0  147.0  105   8   5  116.19    3    caught     2  v Australia
# 130    8.0    6.0    5   2   0  160.00    3    caught     1  v Australia
# 131   55.0   81.0   63   8   0   87.30    3    caught     2  v Australia
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %%
df['Ground'].unique().tolist()
# Out:
# ['Dambulla',
#  'Colombo (RPS)',
#  'Vadodara',
#  'Mohali',
#  'Rajkot',
#  'Nagpur',
#  'Kolkata',
#  'Dhaka',
#  'Jaipur',
#  'Ahmedabad',
#  'Bulawayo',
#  'Harare',
#  'Visakhapatnam',
#  'Guwahati',
#  'Bengaluru',
#  'Chennai',
#  'Durban',
#  'Johannesburg',
#  'Cape Town',
#  'Port Elizabeth',
#  'Centurion',
#  'Delhi',
#  'Mumbai',
#  'Port of Spain',
#  'North Sound',
#  'Kingston',
#  'Southampton',
#  'The Oval',
#  'Cardiff',
#  'Hyderabad (Deccan)',
#  'Cuttack',
#  'Indore',
#  'Melbourne',
#  'Adelaide',
#  'Brisbane',
#  'Sydney',
#  'Hambantota',
#  'Pallekele',
#  'Kochi',
#  'Ranchi',
#  'Dharamsala',
#  'Birmingham',
#  'Pune',
#  'Kanpur',
#  'Napier',
#  'Hamilton',
#  'Wellington',
#  'Fatullah',
#  'Nottingham',
#  'Leeds',
#  'Perth',
#  'Canberra']

# %%
df['Ground'].nunique()
# Out:
# 52

# %% [markdown]
# ### In which ground Virat has scored maximum runs

# %%
df.sort_values(by='Runs',ascending=False).head(1)
# Out:
#       Runs   Mins   BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 117  138.0  202.0  140   6   5  98.57    3    caught     1  v Australia
#
#       Ground Start_Date
# 117  Chennai  22-Oct-15

# %% [markdown]
# ## Slice

# %%
df.loc[[0,1,2],['Runs']]
# Out:
#    Runs
# 0  12.0
# 1  37.0
# 2  25.0

# %%
df.iloc[:,[0,1,2]]
# Out:
#       Runs   Mins   BF
# 0     12.0   33.0   22
# 1     37.0   82.0   67
# 2     25.0   40.0   38
# 3     54.0   87.0   66
# 4     31.0   45.0   46
# ..     ...    ...  ...
# 127   45.0   64.0   51
# 128   65.0  152.0   76
# 129  122.0  147.0  105
# 130    8.0    6.0    5
# 131   55.0   81.0   63
#
# [132 rows x 3 columns]

# %%
df['New']=df['Mins'].apply(lambda x:x*x)
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1  v Australia
# 1     37.0   82.0   67   6   0   55.22    2    caught     2  v Australia
# 2     25.0   40.0   38   4   0   65.78    1   run out     1  v Australia
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1  v Australia
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2  v Australia
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...          ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v Australia
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v Australia
# 129  122.0  147.0  105   8   5  116.19    3    caught     2  v Australia
# 130    8.0    6.0    5   2   0  160.00    3    caught     1  v Australia
# 131   55.0   81.0   63   8   0   87.30    3    caught     2  v Australia
#
#             Ground Start_Date      New
# 0         Dambulla  18-Aug-08   1089.0
# ...

# %%
df.drop('New', axis=1, inplace=True)

# %%
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1  v Australia
# 1     37.0   82.0   67   6   0   55.22    2    caught     2  v Australia
# 2     25.0   40.0   38   4   0   65.78    1   run out     1  v Australia
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1  v Australia
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2  v Australia
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...          ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v Australia
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v Australia
# 129  122.0  147.0  105   8   5  116.19    3    caught     2  v Australia
# 130    8.0    6.0    5   2   0  160.00    3    caught     1  v Australia
# 131   55.0   81.0   63   8   0   87.30    3    caught     2  v Australia
#
#             Ground Start_Date
# 0         Dambulla  18-Aug-08
# ...

# %% [markdown]
# ## Add a column 'Rating' if virat scores >=100 'Excellent' else 'Fine'

# %%
df['Rating'] = df['Runs'].apply(lambda x: 'Excellent' if x >= 100 else 'Fine')

# %%
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos Dismissal  Inns   Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2       lbw     1  v Australia
# 1     37.0   82.0   67   6   0   55.22    2    caught     2  v Australia
# 2     25.0   40.0   38   4   0   65.78    1   run out     1  v Australia
# 3     54.0   87.0   66   7   0   81.81    1    bowled     1  v Australia
# 4     31.0   45.0   46   3   1   67.39    1       lbw     2  v Australia
# ..     ...    ...  ...  ..  ..     ...  ...       ...   ...          ...
# 127   45.0   64.0   51   2   1   88.23    3    caught     2  v Australia
# 128   65.0  152.0   76   2   1   85.52    3    caught     1  v Australia
# 129  122.0  147.0  105   8   5  116.19    3    caught     2  v Australia
# 130    8.0    6.0    5   2   0  160.00    3    caught     1  v Australia
# 131   55.0   81.0   63   8   0   87.30    3    caught     2  v Australia
#
#             Ground Start_Date     Rating
# 0         Dambulla  18-Aug-08       Fine
# ...

# %%
abcd=df[df['Rating']=='Excellent']

# %%
abcd['Ground'].unique()
# Out:
# array(['Kolkata', 'Visakhapatnam', 'Guwahati', 'Cardiff', 'Hambantota',
#        'Port of Spain', 'Harare', 'Napier', 'Fatullah', 'Dharamsala',
#        'Chennai', 'Melbourne', 'Canberra', 'Pune'], dtype=object)

# %%
pd.set_option('display.max_rows',500)

# %%
df
# Out:
#       Runs   Mins   BF  4s  6s      SR  Pos   Dismissal  Inns   Opposition  \
# 0     12.0   33.0   22   1   0   54.54    2         lbw     1  v Australia
# 1     37.0   82.0   67   6   0   55.22    2      caught     2  v Australia
# 2     25.0   40.0   38   4   0   65.78    1     run out     1  v Australia
# 3     54.0   87.0   66   7   0   81.81    1      bowled     1  v Australia
# 4     31.0   45.0   46   3   1   67.39    1         lbw     2  v Australia
# 5      NaN    6.0    2   0   0  100.00    7     not out     1  v Australia
# 6     30.0   53.0   41   3   0   73.17    4      caught     2  v Australia
# 7     10.0   32.0   16   1   0   62.50    3      caught     2  v Australia
# 8     27.0   20.0   19   4   0  142.10    7      bowled     1  v Australia
# 9     54.0   93.0   65   7   0   83.07    4         lbw     1  v Australia
# 10   107.0    NaN  114  11   1   93.85    4      caught     2  v Australia
# ...
